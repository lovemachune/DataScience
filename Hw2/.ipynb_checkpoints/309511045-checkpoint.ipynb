# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
import keras
import numpy as np
import re
from keras import Input
from keras.layers import Embedding, LSTM, concatenate, Dense
from keras.models import Model

# %%
def word_split(mystring):
    str_split = []
    for tmp in mystring:
        tmp = re.sub('[^a-zA-Z0-9\s]+', '', tmp)
        tmp = tmp.split(' ')
        while True:
            if '' not in tmp:
                break
            tmp.remove('')    
        str_split.append(tmp)
    return str_split

# %%
all_data = pd.read_csv("train.csv")
data = all_data['Headline'].to_numpy()
label = all_data['Label'].to_numpy()

# %%
my_split = word_split(data)

# %%
MAX_NUM_WORDS = 10000
tokenizer = keras.preprocessing.text.Tokenizer(num_words=MAX_NUM_WORDS)

# %%
tokenizer.fit_on_texts(my_split)

# %%
x= tokenizer.texts_to_sequences(my_split)
max_seq_len = max([len(seq) for seq in x])
MAX_SEQUENCE_LENGTH = 25
x = keras.preprocessing.sequence.pad_sequences(x,maxlen=MAX_SEQUENCE_LENGTH)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, label, test_size=0.1, random_state = 42)

# %%
NUM_EMBEDDING_DIM = 128

# LSTM 輸出的向量維度
NUM_LSTM_UNITS = 128
top_input = Input(shape=(MAX_SEQUENCE_LENGTH, ), dtype='int32')
embedding_layer = Embedding(MAX_NUM_WORDS, NUM_EMBEDDING_DIM)
top_embedded = embedding_layer(top_input)
shared_lstm = LSTM(NUM_LSTM_UNITS)
top_output = shared_lstm(top_embedded)
dense =  Dense(units=1, activation='linear')
predictions = dense(top_output)
model = Model(inputs=top_input, outputs=predictions)

# %%
model.compile(optimizer='Adam',loss='MSE',metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 25)]              0
# _________________________________________________________________
# embedding_7 (Embedding)      (None, 25, 128)           1280000
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,411,713
# Trainable params: 1,411,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=x_train, y=y_train, validation_data=(x_test,y_test), batch_size=32,epochs=20,shuffle=True)
# Out:
# Epoch 1/20
# 58/58 [==============================] - 1s 22ms/step - loss: 2.2266 - accuracy: 0.0022 - val_loss: 0.6007 - val_accuracy: 0.0049
# Epoch 2/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.4209 - accuracy: 0.0022 - val_loss: 0.5442 - val_accuracy: 0.0049
# Epoch 3/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.2216 - accuracy: 0.0022 - val_loss: 0.5874 - val_accuracy: 0.0049
# Epoch 4/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0937 - accuracy: 0.0022 - val_loss: 0.6203 - val_accuracy: 0.0049
# Epoch 5/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0505 - accuracy: 0.0022 - val_loss: 0.6267 - val_accuracy: 0.0049
# Epoch 6/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0340 - accuracy: 0.0022 - val_loss: 0.6458 - val_accuracy: 0.0049
# Epoch 7/20
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0230 - accuracy: 0.0022 - val_loss: 0.6223 - val_accuracy: 0.0049
# Epoch 8/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0184 - accuracy: 0.0022 - val_loss: 0.6397 - val_accuracy: 0.0049
# Epoch 9/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0167 - accuracy: 0.0022 - val_loss: 0.6404 - val_accuracy: 0.0049
# Epoch 10/20
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0151 - accuracy: 0.0022 - val_loss: 0.6408 - val_accuracy: 0.0049
# Epoch 11/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0151 - accuracy: 0.0022 - val_loss: 0.6310 - val_accuracy: 0.0049
# Epoch 12/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0129 - accuracy: 0.0022 - val_loss: 0.6261 - val_accuracy: 0.0049
# Epoch 13/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0105 - accuracy: 0.0022 - val_loss: 0.6358 - val_accuracy: 0.0049
# Epoch 14/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0098 - accuracy: 0.0022 - val_loss: 0.6439 - val_accuracy: 0.0049
# Epoch 15/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0086 - accuracy: 0.0022 - val_loss: 0.6277 - val_accuracy: 0.0049
# Epoch 16/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0091 - accuracy: 0.0022 - val_loss: 0.6232 - val_accuracy: 0.0049
# Epoch 17/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0070 - accuracy: 0.0022 - val_loss: 0.6279 - val_accuracy: 0.0049
# Epoch 18/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0061 - accuracy: 0.0022 - val_loss: 0.6290 - val_accuracy: 0.0049
# Epoch 19/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0064 - accuracy: 0.0022 - val_loss: 0.6267 - val_accuracy: 0.0049
# Epoch 20/20
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0082 - accuracy: 0.0022 - val_loss: 0.6317 - val_accuracy: 0.0049

# %%
results = model.evaluate(x_test, y_test, batch_size=128)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6317 - accuracy: 0.0049

# %%
test_data = pd.read_csv("test.csv")
data = test_data['Headline'].to_numpy()
label = test_data['Label'].to_numpy()

# %%
test_split = word_split(data)
x_test= tokenizer.texts_to_sequences(test_split)
max_seq_len = max([len(seq) for seq in x_test])
MAX_SEQUENCE_LENGTH = 25
x_test = keras.preprocessing.sequence.pad_sequences(x_test,maxlen=MAX_SEQUENCE_LENGTH)

# %%
y_pre = model.predict(x_test)

# %%
print(y_pre)
# Out:
# [[3.0768807]
#  [2.706529 ]
#  [2.9559648]
#  [2.6946697]
#  [3.0924385]
#  [2.9758039]
#  [2.316033 ]
#  [3.2757995]
#  [3.2431397]
#  [2.2609587]
#  [3.2479632]
#  [3.5005813]
#  [2.931682 ]
#  [2.9758236]
#  [2.7231138]
#  [2.54774  ]
#  [3.8070252]
#  [2.8423195]
#  [2.5946152]
#  [2.116478 ]
#  [2.6708167]
#  [3.1830525]
#  [3.067257 ]
#  [2.8596241]
#  [3.5902002]
#  [3.1898968]
#  [2.885566 ]
#  [2.5494807]
#  [3.2189722]
#  [2.7376943]
#  [2.688157 ]
#  [2.7162097]
#  [2.5561676]
#  [2.307369 ]
#  [2.9364307]
#  [2.195771 ]
#  [2.943375 ]
#  [2.179076 ]
#  [3.3726056]
#  [2.5766423]
#  [3.6232762]
#  [2.0030375]
#  [3.6917448]
#  [2.952646 ]
#  [2.7745183]
#  [2.4672794]
#  [2.854521 ]
#  [2.7661312]
#  [2.223356 ]
#  [2.9804606]
#  [3.115323 ]
#  [3.1343863]
#  [2.6460316]
#  [3.0401967]
#  [2.9399722]
#  [3.1987314]
#  [3.2446373]
#  [2.6765547]
#  [2.6526473]
#  [2.9142327]
#  [2.1462362]
#  [3.0120554]
#  [2.4441245]
#  [3.7603626]
#  [3.054699 ]
#  [4.1713915]
#  [2.4301994]
#  [2.2992213]
#  [3.2063558]
#  [3.4448621]
#  [3.642676 ]
#  [3.4453027]
#  [3.8319292]
#  [2.9381044]
#  [2.7748148]
#  [2.880195 ]
#  [3.0953238]
#  [3.158823 ]
#  [2.8743618]
#  [2.9234965]
#  [2.747121 ]
#  [2.6184952]
#  [3.1262772]
#  [3.400839 ]
#  [3.6056352]
#  [3.4177058]
#  [3.0733273]
#  [3.0918047]
#  [2.837278 ]
#  [1.935357 ]
#  [3.190387 ]
#  [2.9070141]
#  [2.7996924]
#  [2.7588844]
#  [3.4986963]
#  [2.763642 ]
#  [3.206319 ]
#  [2.9806502]
#  [3.2303052]
#  [2.9014595]
#  [2.9648032]
#  [2.4582403]
#  [2.6540205]
#  [3.3844497]
#  [3.3991864]
#  [2.8085964]
#  [2.477771 ]
#  [2.2486022]
#  [3.2086332]
#  [1.9052043]
#  [3.3395653]
#  [2.6184068]
#  [2.632713 ]
#  [2.4287794]
#  [3.3158262]
#  [2.5722313]
#  [2.9611394]
#  [3.4278152]
#  [2.9496453]
#  [2.4606402]
#  [2.9406338]
#  [2.4895265]
#  [3.2310274]
#  [3.2003565]
#  [2.8453581]
#  [3.1399858]
#  [2.9036324]
#  [2.4064643]
#  [2.5679286]
#  [2.8673906]
#  [2.718662 ]
#  [3.0360997]
#  [2.8865347]
#  [2.5179036]
#  [2.348233 ]
#  [2.686571 ]
#  [2.8378048]
#  [2.4802291]
#  [2.4363878]
#  [3.3675716]
#  [3.3170605]
#  [2.169058 ]
#  [2.80363  ]
#  [2.963957 ]
#  [1.9709895]
#  [2.7076871]
#  [2.921302 ]
#  [2.776078 ]
#  [3.4867053]
#  [2.7310522]
#  [3.8768728]
#  [2.5027518]
#  [3.0167322]
#  [2.9346788]
#  [3.0104697]
#  [3.3050187]
#  [3.3423824]
#  [3.1192472]
#  [3.4948475]
#  [3.0712018]
#  [2.893007 ]
#  [3.0495975]
#  [3.1174629]
#  [2.6777713]
#  [3.4193523]
#  [2.6391249]
#  [2.8869874]
#  [3.096309 ]
#  [3.638068 ]
#  [2.2266252]
#  [2.969432 ]
#  [3.5933366]
#  [2.4315424]
#  [2.640354 ]
#  [2.7012696]
#  [3.29628  ]
#  [2.2570536]
#  [2.4281385]
#  [3.5034873]
#  [3.430898 ]
#  [2.2484658]
#  [2.9525898]
#  [3.4435275]
#  [2.8339102]
#  [3.0344613]
#  [3.7928178]
#  [2.4492655]
#  [3.2780793]
#  [3.9629521]
#  [3.6937952]
#  [2.4894722]
#  [3.8547862]
#  [2.833725 ]
#  [3.2647927]
#  [3.2640715]
#  [3.0345194]
#  [3.2529616]
#  [3.9824402]
#  [3.6800048]
#  [2.8436902]
#  [2.8014224]
#  [2.9870355]
#  [3.0727503]
#  [3.534558 ]
#  [3.1533172]
#  [2.9727612]
#  [2.7036152]
#  [2.443469 ]
#  [3.1399488]
#  [2.4725254]
#  [3.1794713]
#  [3.0898972]
#  [2.304034 ]
#  [3.0710166]
#  [2.6947558]
#  [2.8608172]
#  [2.1549892]
#  [3.0717947]
#  [2.9897754]
#  [2.784478 ]
#  [3.5744202]
#  [3.3646066]
#  [3.4350617]
#  [2.6386142]
#  [2.8515804]
#  [3.3690023]
#  [2.901324 ]]

# %%
import csv
with open('output.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow('[Label]')
    writer.writerows(y_pre)
